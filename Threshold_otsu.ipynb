# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilvkth/325_Image_processing/blob/main/Threshold_otsu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data
import matplotlib.pyplot as plt

img = data.camera()

plt.imshow(img, cmap='gray')
plt.title('Camera Image')
plt.axis('off')
plt.show()

# %%
from skimage import data
import cv2
import matplotlib.pyplot as plt

img = data.camera()

threshold, otsu = cv2.threshold(
    img,
    0,
    255,
    cv2.THRESH_BINARY + cv2.THRESH_OTSU
)

print("Otsu Threshold =", threshold)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(otsu, cmap='gray')
plt.title('Otsu Threshold')
plt.axis('off')

plt.show()
# Out:
# Otsu Threshold = 102.0

# %%
from skimage import data
import cv2
import matplotlib.pyplot as plt

img = data.camera()

adaptive = cv2.adaptiveThreshold(
    img,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    11,
    2
)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(adaptive, cmap='gray')
plt.title('Adaptive Threshold')
plt.axis('off')

plt.show()

# %%
# Plot
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(otsu, cmap='gray')
plt.title('Otsu Threshold')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(adaptive, cmap='gray')
plt.title('Adaptive Threshold')
plt.axis('off')

plt.show()
